# %% [markdown]
# # Exercise 3

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# The following code will load all `*.pickle` files that you created in the other notebooks, and plot the saved losses.

# %%
import glob
import pickle

plt.figure(figsize=(20, 20))
for f in sorted(glob.glob('*.pickle')):
    with open(f, 'rb') as handle:
        losses = pickle.load(handle)
    plt.plot(losses, label=" ".join(f.split('.')[0].split('_')[1:]))

# plt.yscale('log')
plt.legend()
plt.show()

# %% [markdown]
# I'm not exactly sure what I'm doing wrong. The more sofisticated optimizers seem to yield worse results and show slower convergence than the standard algorithms...
